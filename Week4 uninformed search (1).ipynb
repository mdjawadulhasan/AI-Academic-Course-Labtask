# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %%
romanian_map.keys()
# Out:
# dict_keys(['Arad', 'Zerind', 'Oradea', 'Sibiu', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu', 'Fagaras', 'Pitesti', 'Bucharest', 'Giurgiu', 'Urziceni', 'Hirsova', 'Eforie', 'Vaslui', 'Iasi', 'Neamt'])

# %%
romanian_map['Arad'].keys()
# Out:
# dict_keys(['Sibiu', 'Zerind', 'Timisoara'])

# %%
#romanian_map['Arad']

# %%
romanian_map['Arad']['Timisoara']
# Out:
# 118

# %% [markdown]
# # BFS

# %%
from queue import Queue

def bfs(startingNode, destinationNode):
    visited = {} # to store expanded nodes
    traversal_output = [] # to store the order of traversal
    frontier = Queue()

    for city in romanian_map.keys():
        visited[city] = False
        
    
    node = {'City':startingNode,'Distance':0, 'Path':[startingNode]}
    frontier.put(node)    # arad
    
    while not frontier.empty():
        node = frontier.get()     # selceting the node to expand
        u = node['City']
        visited[u] = True
        traversal_output.append(u)
        
        for v in romanian_map[u].keys():
            if not visited[v]: # process if v is not expanded                
                d = node['Distance'] + romanian_map[u][v] 
                p =  node['Path'] + [v]
                frontier.put({'City':v,'Distance':d,'Path': p})# store the new child node in the frontier
                if v == destinationNode: # goal test
                    print(d)
                    print(traversal_output)
                    return p # breaking from while
    print('not found')

# %%
bfs('Arad','Drobeta')
# Out:
# 486
# ['Arad', 'Sibiu', 'Zerind', 'Timisoara', 'Oradea', 'Fagaras', 'Rimnicu', 'Oradea', 'Lugoj', 'Bucharest', 'Craiova']
# ['Arad', 'Sibiu', 'Rimnicu', 'Craiova', 'Drobeta']

# %% [markdown]
# #BFS![BFS.PNG](attachment:BFS.PNG)

# %% [markdown]
# # DFS
# Impement DFS using stack,
# Implement stack using list (push)

# %%
Stack = []
Stack.append('cc') # insert
Stack.append('bb')
Stack.append('aa')
print(Stack)
print(Stack.pop(-1)) # delete
print(Stack)
# Out:
# ['cc', 'bb', 'aa']
# aa
# ['cc', 'bb']

# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}


def dfs(startingNode, destinationNode):
  reached = []  # to store reached (generated) nodes
  expand_sequence = []  # to store the order of nodes expanded
  frontier = []

  snode = {'City': startingNode, 'Path cost': 0, 'Path': [startingNode]}
  frontier.append(snode)  # insert the starting node
  reached.append(startingNode)

  while len(frontier) > 0:
    unode=frontier[-1]              #Storing thhe top value from stack
    u = unode['City']
    expand_sequence.append(u)

    if u == destinationNode:       #checking the expand city name
        print(frontier[-1])         #printing the goal city
        print(expand_sequence)
        return vnode['Path']

    unode = frontier.pop(-1)
    for v in romanian_map[u].keys():
      if v not in reached:  # process if v is not reached (generated) yet
        cost = unode['Path cost'] + romanian_map[u][v]
        path = unode['Path'] + [v]
        vnode = {'City': v, 'Path cost': cost, 'Path': path}
        frontier.append(vnode)  # store the new child node in the frontier
        reached.append(v)

  print('Failed')
dfs('Arad','Drobeta')
# Out:
# {'City': 'Drobeta', 'Path cost': 374, 'Path': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']}
# ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']
# ['Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta']

# %% [markdown]
# # DFS![DFS.PNG](attachment:DFS.PNG)
