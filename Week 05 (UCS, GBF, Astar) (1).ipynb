# %% [markdown]
# ![map.JPG](attachment:map.JPG)

# %%
romanian_map = {
    'Arad': {'Sibiu':140, 'Zerind':75, 'Timisoara':118},
    'Zerind': {'Arad':75, 'Oradea':71},
    'Oradea': {'Zerind':71, 'Sibiu': 151},
    'Sibiu': {'Arad':140, 'Oradea':151, 'Fagaras':99, 'Rimnicu':80},
    'Timisoara': {'Arad': 118, 'Lugoj':111},
    'Lugoj': {'Timisoara':111, 'Mehadia':70},
    'Mehadia': {'Lugoj': 70, 'Drobeta':75},
    'Drobeta': {'Mehadia':75, 'Craiova':120},
    'Craiova': {'Drobeta': 120, 'Rimnicu': 146, 'Pitesti': 138},
    'Rimnicu': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu':99, 'Bucharest':211},
    'Pitesti': {'Rimnicu': 97, 'Craiova':138, 'Bucharest':101},
    'Bucharest': {'Fagaras':211, 'Pitesti': 101, 'Giurgiu':90, 'Urziceni':85},
    'Giurgiu': {'Bucharest': 90},
    'Urziceni': {'Bucharest': 85, 'Vaslui':142, 'Hirsova':98},
    'Hirsova': {'Urziceni':98, 'Eforie':86},
    'Eforie': {'Hirsova':86},
    'Vaslui': {'Iasi': 92, 'Urziceni':142},
    'Iasi': {'Vaslui':92, 'Neamt': 87},
    'Neamt': {'Iasi':87}
}

# %% [markdown]
# # Uniform Cost Search

# %%
from queue import PriorityQueue


def ucs(startingNode, destinationNode):
    expanded = [] # to store expanded nodes
    frontier = PriorityQueue()

    snode = (0,startingNode,[startingNode]) #(g(n) = path cost, city name, path)
    frontier.put(snode)
    
    while not frontier.empty():
        unode = frontier.get() # select a node for expansion
        u = unode[1] 
        if u == destinationNode:# goal test            
            print(unode)
            print(expanded)
            return unode[2] # path
        expanded.append(u)
        for v in romanian_map[u].keys():#expanding            
            if v not in expanded:
                cost = unode[0] + romanian_map[u][v]
                path = unode[2] + [v]
                frontier.put((cost,v,path))
                print(v+ ", Cost: " +str(cost))
    print('Failed')

# %%
ucs('Timisoara', 'Bucharest') # change source and destination
# Out:
# Arad, Cost: 118
# Lugoj, Cost: 111
# Mehadia, Cost: 181
# Sibiu, Cost: 258
# Zerind, Cost: 193
# Drobeta, Cost: 256
# Oradea, Cost: 264
# Craiova, Cost: 376
# Oradea, Cost: 409
# Fagaras, Cost: 357
# Rimnicu, Cost: 338
# Craiova, Cost: 484
# Pitesti, Cost: 435
# Bucharest, Cost: 568
# Pitesti, Cost: 514
# Bucharest, Cost: 536
# Bucharest, Cost: 615
# (536, 'Bucharest', ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest'])
# ['Timisoara', 'Lugoj', 'Arad', 'Mehadia', 'Zerind', 'Drobeta', 'Sibiu', 'Oradea', 'Rimnicu', 'Fagaras', 'Craiova', 'Oradea', 'Pitesti', 'Craiova', 'Pitesti']
# ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']

# %% [markdown]
# ![UCS.PNG](attachment:UCS.PNG)

# %% [markdown]
# # Greedy Best First Search

# %%
# SLD heuristic for the destination (Bucharest)
h = {'Arad': 366,'Zerind':  374,'Oradea': 380,'Sibiu': 253,
    'Timisoara': 329,'Lugoj': 244,'Mehadia': 241,'Drobeta': 242,
    'Craiova': 160,'Rimnicu': 193,'Fagaras': 176,'Pitesti': 100,
    'Bucharest': 0,'Giurgiu': 77,'Urziceni': 80,'Hirsova': 151,
    'Eforie': 161,'Vaslui': 199,'Iasi': 226,'Neamt': 234
}

# %%
from queue import PriorityQueue

def gbfs(startingNode, destinationNode):
    expanded = [] # to store expanded nodes
    frontier = PriorityQueue()

    snode = (h[startingNode],startingNode,[startingNode],0) # (h, city, path, path cost)
    frontier.put(snode)

    while not frontier.empty():
        unode = frontier.get() 
        u = unode[1]
        
        if u== destinationNode:#Goal Test            
            print(unode)
            print(expanded)
            return unode[2] #path
        expanded.append(u)
        for v in romanian_map[u].keys():            
            if v not in expanded:
                cost = unode[3] + romanian_map[u][v]
                path = unode[2]+[v]
                frontier.put((h[v],v,path, cost))   
    print('Failed')

# %%
gbfs('Timisoara', 'Bucharest') # change source only
# Out:
# (0, 'Bucharest', ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest'], 615)
# ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti']
# ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']

# %% [markdown]
# ![GBFS.PNG](attachment:GBFS.PNG)

# %% [markdown]
# # A*

# %%
def Astar(startingNode, destinationNode):
    expanded = []  # to store expanded nodes
    frontier = PriorityQueue()

    snode = (h[startingNode], startingNode, [startingNode], 0)  # (h, city, path, path cost)
    frontier.put(snode)

    while not frontier.empty():
        unode = frontier.get()
        u = unode[1]

        if u == destinationNode:  # Goal Test
            print(unode)
            print(expanded)
            return unode[2]  # path
        expanded.append(u)
        # print("Parrent City : " + u)
        # print("------------------------------------")
        for v in romanian_map[u].keys():
            # print("Child : "+v)
            val= unode[3] + romanian_map[u][v]+h[v]
            # if v in expanded :
                # print("This is in expanded")
                # print("h(n)")
                # print(h[v])
                # print("g(n)")
                # print(unode[3] + romanian_map[u][v])
                # print(val)
            if v not in expanded:
                cost = unode[3] + romanian_map[u][v]
                path = unode[2] + [v]
                frontier.put((h[v]+cost, v, path, cost))
                # print("h(n)")
                # print(h[v])
                # print("g(n)")
                # print(cost)
                # print((h[v]+cost))

    print('Failed')

Astar('Timisoara', 'Bucharest')  # Timisoara is the  source here
# Out:
# (536, 'Bucharest', ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest'], 536)
# ['Timisoara', 'Lugoj', 'Mehadia', 'Arad', 'Drobeta', 'Sibiu', 'Rimnicu', 'Fagaras', 'Pitesti']
# ['Timisoara', 'Arad', 'Sibiu', 'Rimnicu', 'Pitesti', 'Bucharest']

# %% [markdown]
# ![Astar.PNG](attachment:Astar.PNG)
